# %% [markdown]
# # Assignment #0 - Data and Visualization
#
# Due: Jan 29 (Tuesday) 11:00 pm
#
# ## Srishti Tiwari
#
#
# # Overview
#
#
# In this assignment, I have done reading assignment summary of Linear Algebra, Probability and Information theory.
# I have also got familiar to the tools including Python, numpy, matplotlib, pandas, and Jupyter notebook by creating data visualizations from datasets. I have included one data for classification and one for regression from Kaggle. The data is more than 10,000 samples and contains more than 10 feature values.
# This helped me to understand data and its properties in a better manner.
#
#
# # Review
#
# ## Linear Algebra
#
# Linear algebra is a branch of mathematics that is widely used throughout scienceand engineering.
#
# A good understanding of linear algebra is essential for understanding and workingwith many machine learning algorithms, especially deep learning algorithms.
#
# ### Scalars, Vectors, Matrices and Tensors
#
# The study of linear algebra involves several types of mathematical objects:
# Scalars:A scalar is just a single number, we usually five scalars a lowercase variable name
# Vectors: A vector is an array of numbers. The numbers are arranged in order. We can identify each individual number by its index in that ordering.
# Matrices: In general terms, a matrix is an array of numbers that are arranged into rows and columns.
#
# #### Matrices and Matrix Notation
# A matrix arranges numbers into rows and columns, like this:
#
# $$A = \begin{bmatrix}
#   1 ; 2 ; 3 \\
#   4 ; 5 ; 6
#  \end{bmatrix}
# $$
# Note that matrices are generally named as a capital letter. We refer to the elements of the matrix using the lower case equivalent with a subscript row and column indicator, like this:
#
# $$A = \begin{bmatrix}
#   a_{1,1} ; a_{1,2} ; a_{1,3} \\
#   a_{2,1} ; a_{2,2} ; a_{2,3}
#  \end{bmatrix}
# $$
#
# #### Tensors
# In some cases we will need an array with more than two axes.In the general case, an array of numbers arranged on a regular grid with avariable number of axes is known as a tensor.
#
# You can transpose a matrix, that is switch the orientation of its rows and columns. You indicate this with a superscript T, like this:
#
# $$\begin{bmatrix}1 ; 2 ; 3 \\4 ; 5 ; 6\end{bmatrix}^{T} = \begin{bmatrix}1 ; 4\\2 ; 5\\3 ; 6 \end{bmatrix}$$
#
# #### Matrix Multiplication
#
# Multiplying matrices is a little more complex than the operations we've seen so far. There are two cases to consider, scalar multiplication (multiplying a matrix by a single number), and dot product matrix multiplication (multiplying a matrix by another matrix.
#
# #### Scalar Multiplication
# To multiply a matrix by a scalar value, you just multiply each element by the scalar to produce a new matrix:
#
# $$2 \times \begin{bmatrix}1 ; 2 ; 3 \\4 ; 5 ; 6\end{bmatrix} = \begin{bmatrix}2 ; 4 ; 6 \\8 ; 10 ; 12\end{bmatrix}$$
#
#
# #### Inverse of a Matrix
#
# For matrix division, we multiply by the inverse of a matrix:
#
# $$A \div B = A \cdot B^{-1}$$
# The inverse of B is B-1 as long as the following equation is true:
#
# $$B \cdot B^{-1} = B^{-1} \cdot B = I$$
#
# #### Eigendecomposition
#
# So we've learned a little about eigenvalues and eigenvectors; but you may be wondering what use they are. Well, one use for them is to help decompose transformation matrices.
#
# Recall that previously we found that a matrix transformation of a vector changes its magnitude, amplitude, or both. Without getting too technical about it, we need to remember that vectors can exist in any spatial orientation, or basis; and the same transformation can be applied in different bases.
#
# We can decompose a matrix using the following formula:
#
# $$A = Q \Lambda Q^{-1}$$
# Where A is a trasformation that can be applied to a vector in its current base, Q is a matrix of eigenvectors that defines a change of basis, and Λ is a matrix with eigenvalues on the diagonal that defines the same linear transformation as A in the base defined by Q.
#
# Let's look at these in some more detail. Consider this matrix:
#
# $$A=\begin{bmatrix}3 &amp; 2\\1 &amp; 0\end{bmatrix}$$
#
#
#
# ## Probability Theory
#
#
# ### Probability
# Some basic definitions and principles.
# An experiment or trial is an action with an uncertain outcome, such as tossing a coin.
# A sample space is the set of all possible outcomes of an experiment. In a coin toss, there's a set of two possible oucomes (heads and tails).
# A sample point is a single possible outcome - for example, heads)
# An event is a specific outome of single instance of an experiment - for example, tossing a coin and getting tails.
# Probability is a value between 0 and 1 that indicates the likelihood of a particular event, with 0 meaning that the event is impossible, and 1 meaning that the event is inevitable. In general terms, it's calculated like this:
# $$\text{probability of an event} = \frac{\text{Number of sample points that produce the event}}{\text{Total number of sample points in the sample space}} $$
#
# #### Probability Notation
# When we express probability, we use an upper-case P to indicate probability and an upper-case letter to represent the event. So to express the probability of throwing a 7 as an event valled A, we could write:
#
# $$P(A) = 0.167 $$
#
# #### Conditional Probability and Dependence
#
# Events can be:
#
# * Independent (events that are not affected by other events)
# * Dependent (events that are conditional on other events)
# * Mutually Exclusive (events that can't occur together)
#
# ### Information Theory
#
# Information theory is a branchof applied mathematics that revolves around quantifying how much information is present in a signal.
#
# The basic intuition behind information theory is that learning that an unlikely event has occurred is more informative than learning that a likely event has occurred. A message saying “the sun rose this morning” is so uninformative as to be unnecessary to send, but a message saying “there was a solar eclipse this morning” is very informative.We would like to quantify information in a way that formalizes this intuition.
#
# • Likely events should have low information content, and in the extreme case,events that are guaranteed to happen should have no information content whatsoever.
#
# • Less likely events should have higher information content.
#
# • Independent events should have additive information. For example, ﬁndingout that a tossed coin has come up as heads twice should convey twice as much information as ﬁnding out that a tossed coin has come up as headsonce.

# %% [markdown]
# ## Introduction of data for regression & source
#
# ### Airbnb dataset
#
# I collected this dataset from kaggle.com. It consists of two files, training data and testing data csv files.
#
#
# ## Reading the data
#
# The training data consist of the following columns:
#
# id : Record identifier log_price : log(price) [The logarithm used is natural log] ..... : 25 features for the listing There are five files provided for this competition:
#
# train.csv : Training data
# test.csv : Test data

# %% [markdown]
# I have used following libraries for various data visualization operations:

# %%
from IPython.display import display
import numpy as np
#Visualization
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
import seaborn as sns
from wordcloud import WordCloud
from collections import Counter
# %matplotlib inline

# %%
data_train = pd.read_csv('train.csv')
data_test = pd.read_csv('test.csv')
#checking the data size
print("\ntrain data size: {} ".format(data_train.shape))
print("test data size: {} ".format(data_test.shape))
# Out:
# train data size: (74111, 29)
# test data size: (25458, 28)

# %% [markdown]
# ## Preprocessing of the data

# %%
print(data_train.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74111 entries, 0 to 74110
# Data columns (total 29 columns):
# id                        74111 non-null int64
# log_price                 74111 non-null float64
# property_type             74111 non-null object
# room_type                 74111 non-null object
# amenities                 74111 non-null object
# accommodates              74111 non-null int64
# bathrooms                 73911 non-null float64
# bed_type                  74111 non-null object
# cancellation_policy       74111 non-null object
# cleaning_fee              74111 non-null bool
# city                      74111 non-null object
# description               74111 non-null object
# first_review              58247 non-null object
# host_has_profile_pic      73923 non-null object
# host_identity_verified    73923 non-null object
# host_response_rate        55812 non-null object
# host_since                73923 non-null object
# ...

# %%
print(data_test.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25458 entries, 0 to 25457
# Data columns (total 28 columns):
# id                        25458 non-null int64
# property_type             25458 non-null object
# room_type                 25458 non-null object
# amenities                 25458 non-null object
# accommodates              25458 non-null int64
# bathrooms                 25379 non-null float64
# bed_type                  25458 non-null object
# cancellation_policy       25458 non-null object
# cleaning_fee              25458 non-null bool
# city                      25458 non-null object
# description               25444 non-null object
# first_review              20022 non-null object
# host_has_profile_pic      25403 non-null object
# host_identity_verified    25403 non-null object
# host_response_rate        19152 non-null object
# host_since                25403 non-null object
# instant_bookable          25458 non-null object
# ...

# %%
data_train.sample(10)
# Out:
#              id  log_price property_type        room_type  \
# 17480   1363336   4.605170     Apartment     Private room
# 74049   6932935   4.828314     Apartment     Private room
# 22721  16831974   5.192957     Apartment  Entire home/apt
# 21404   8918081   4.499810     Apartment     Private room
# 4898   13448456   3.401197     Apartment     Private room
# 63347   9136810   3.912023     Apartment     Private room
# 19422  14979803   5.247024   Condominium  Entire home/apt
# 28067    957642   4.094345     Apartment     Private room
# 64469  19282136   5.857933     Apartment  Entire home/apt
# 3905    4902855   4.094345     Apartment     Private room
#
#                                                amenities  accommodates  \
# 17480  {"Wireless Internet",Kitchen,Washer,Dryer,Esse...             2
# 74049  {TV,"Cable TV",Internet,"Wireless Internet","A...             1
# 22721  {TV,Internet,"Wireless Internet","Air conditio...             2
# ...

# %%
data_test.sample(10)
# Out:
#              id property_type        room_type  \
# 10776   8227513     Apartment  Entire home/apt
# 8996   13172417         House     Private room
# 21474   2254428     Apartment  Entire home/apt
# 19338    958435         House     Private room
# 18450  17419611     Apartment     Private room
# 12499   3175726     Apartment  Entire home/apt
# 23360  13265569     Apartment  Entire home/apt
# 10603  12207340     Apartment     Private room
# 18864  17316535     Apartment  Entire home/apt
# 4931   10250724   Condominium  Entire home/apt
#
#                                                amenities  accommodates  \
# 10776  {TV,"Cable TV",Internet,"Wireless Internet","A...             2
# 8996   {TV,"Cable TV",Internet,"Wireless Internet","A...             2
# 21474  {TV,"Wireless Internet","Air conditioning",Kit...             3
# 19338  {Internet,"Wireless Internet","Air conditionin...             2
# 18450  {"Wireless Internet","Air conditioning",Kitche...             2
# ...

# %%
data_train.columns.values
# Out:
# array(['id', 'log_price', 'property_type', 'room_type', 'amenities',
#        'accommodates', 'bathrooms', 'bed_type', 'cancellation_policy',
#        'cleaning_fee', 'city', 'description', 'first_review',
#        'host_has_profile_pic', 'host_identity_verified',
#        'host_response_rate', 'host_since', 'instant_bookable',
#        'last_review', 'latitude', 'longitude', 'name', 'neighbourhood',
#        'number_of_reviews', 'review_scores_rating', 'thumbnail_url',
#        'zipcode', 'bedrooms', 'beds'], dtype=object)

# %%
data_test.columns.values
# Out:
# array(['id', 'property_type', 'room_type', 'amenities', 'accommodates',
#        'bathrooms', 'bed_type', 'cancellation_policy', 'cleaning_fee',
#        'city', 'description', 'first_review', 'host_has_profile_pic',
#        'host_identity_verified', 'host_response_rate', 'host_since',
#        'instant_bookable', 'last_review', 'latitude', 'longitude', 'name',
#        'neighbourhood', 'number_of_reviews', 'review_scores_rating',
#        'thumbnail_url', 'zipcode', 'bedrooms', 'beds'], dtype=object)

# %% [markdown]
# ## Visualization of the data

# %%
data_train.plot(kind='scatter', x='latitude', y='longitude')

# %% [markdown]
# We can observe through scatter plot that the airbnb business is focussed in major cities of US.

# %%
#correlation matrix
corrmat = data_train.corr(method = 'spearman')
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %% [markdown]
# Correlation matrix is displaying the correlation between various attributes.

# %%
data_train['city'].value_counts().plot(kind='bar')
plt.title('Number of Listings per City - Train')
plt.xlabel('City')
plt.ylabel('Count')
plt.show()

data_test['city'].value_counts().plot(kind='bar')
plt.title('Number of Listings per City - Test')
plt.xlabel('City')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# We observe the number of listings per city. We can find that NYC is the biggest city in terms of Airbnb listings.

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data_train.groupby([
        'city', 'cancellation_policy']).log_price.mean().unstack(),annot=True, fmt=".0f")

# %% [markdown]
# In the heatmap we observe the correlation between prices, cities and the cancellation policies. Higher the cancellation prices, higher the prices.

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data_train.groupby(['property_type', 'bedrooms']).log_price.mean().unstack(), annot=True, fmt=".0f")

# %% [markdown]
# This heatmap groups the data by property type and bedrooms and shows the relation between the prices. We can see that as the bedrooms go higher, prices go higher. Also if the property type is House, Apartment or Villa, prices are higher.

# %%
# Start with one review:
text = data_train.amenities[0]

# Create and generate a word cloud image:
# wordcloud = WordCloud().generate(text)
wordcloud = WordCloud(max_font_size=100, max_words=1000, background_color="white", width=800, height=500).generate(text)
plt.figure(figsize = (10, 8)) 
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %% [markdown]
# Word cloud of amenities is generated. Most common amenities include Internet, heating, Kitchen etc.

# %%
data_train.groupby(['city']).plot(kind='scatter', x='latitude', y='longitude', legend='city')
# Out:
# city
# Boston     AxesSubplot(0.125,0.125;0.775x0.755)
# Chicago    AxesSubplot(0.125,0.125;0.775x0.755)
# DC         AxesSubplot(0.125,0.125;0.775x0.755)
# LA         AxesSubplot(0.125,0.125;0.775x0.755)
# NYC        AxesSubplot(0.125,0.125;0.775x0.755)
# SF         AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %% [markdown]
# In the scatter graph we are grouping data by city and displaying the density of listings in those cities.

# %%
g = sns.lmplot(x="log_price", y="number_of_reviews", col="city", col_wrap=3, hue='cancellation_policy', data=data_train)
g.set(ylim=(0, 800))

# %% [markdown]
# In this plot we find the relationship between number of reviews, prices and cities.

# %%
neighbordata = data_train.copy()
plt.figure(figsize = (12, 100))
sns.boxplot(y = 'neighbourhood', x = 'log_price',  data = neighbordata, orient="h")
xt = plt.xticks()

# %% [markdown]
# This box plot displays the correlation between neighbourhoods and price ranges due to those. We can see that neighbourhood "Brooklyn Heights" is the costliest.

# %% [markdown]
# ## Preliminary observation

# %% [markdown]
# #### Some observations from the data visualizations:
#
# 1. The box plot displays the correlation between neighbourhoods and price ranges due to those. We can see that neighbourhood "Brooklyn Heights" is the costliest.
#
# 2. In this plot we find the relationship between number of reviews, prices and cities.
#
# 3. In the scatter graph we are grouping data by city and displaying the density of listings in those cities.
#
# 4. Word cloud of amenities is generated. Most common amenities include Internet, heating, Kitchen etc.
#
# 5. The heatmap groups the data by property type and bedrooms and shows the relation between the prices. We can see that as the bedrooms go higher, prices go higher. Also if the property type is House, Apartment or Villa, prices are higher.
#
# 6. We observe the number of listings per city. We can find that NYC is the biggest city in terms of Airbnb listings.
#
# 7. Correlation matrix is displaying the correlation between various attributes.
#
# 8. We can observe through scatter plot that the airbnb business is focussed in major cities of US.

# %% [markdown]
# # Introduction of data for Classification & source
#
# ## Kickstarter projects
#
# The purpose of this work is to analyze data and build a classifier to predict successfulness of the Kickstarter campaign based on historical observations and trends.
#
# In this kernel, you will discover a suite of techniques for data transformation (pandas), visualization (matplotlib, seaborn) and classification (sklearn, Light GBM), which could be used as a guidelines to give enough information on each method to get started with a working code example.
#
# Dataset consists of 300K projects with following features:
#
# 1. ID internal kickstarter id
# 2. name name of project - A project is a finite work with a clear goal that you’d like to bring to life. Think albums, books, or films.
# 3. category category
# 4. main_category category of campaign
# 5. currency currency used to support
# 6. deadline deadline for crowdfunding
# 7. goal fundraising goal - The funding goal is the amount of money that a creator needs to complete their project.
# 8. launched date launched
# 9. pledged amount pledged by "crowd"
# 10. state Current condition the project is in
# 11. backers number of backers
# 12. country country pledged from
# 13. usd pledged amount of money pledged
# 14. Goal amount in USD

# %% [markdown]
# ## Reading & Preprocessing of the data

# %%
# read in dataset
kick = pd.read_csv('ks-projects-201801.csv', encoding='latin1')

kick.shape
# Out:
# (378661, 15)

# %%
kick.head()
# Out:
#            ID                                               name  \
# 0  1000002330                    The Songs of Adelaide & Abullah
# 1  1000003930      Greeting From Earth: ZGAC Arts Capsule For ET
# 2  1000004038                                     Where is Hank?
# 3  1000007540  ToshiCapital Rekordz Needs Help to Complete Album
# 4  1000011046  Community Film Project: The Art of Neighborhoo...
#
#          category main_category currency    deadline     goal  \
# 0          Poetry    Publishing      GBP  2015-10-09   1000.0
# 1  Narrative Film  Film & Video      USD  2017-11-01  30000.0
# 2  Narrative Film  Film & Video      USD  2013-02-26  45000.0
# 3           Music         Music      USD  2012-04-16   5000.0
# 4    Film & Video  Film & Video      USD  2015-08-29  19500.0
#
#               launched  pledged     state  backers country  usd pledged  \
# 0  2015-08-11 12:12:28      0.0    failed        0      GB          0.0
# ...

# %%
# name of the columns
kick.columns
# Out:
# Index(['ID', 'name', 'category', 'main_category', 'currency', 'deadline',
#        'goal', 'launched', 'pledged', 'state', 'backers', 'country',
#        'usd pledged', 'usd_pledged_real', 'usd_goal_real'],
#       dtype='object')

# %%
# number of missing values per column
kick.isnull().sum().sort_values(ascending = False)
# Out:
# usd pledged         3797
# name                   4
# usd_goal_real          0
# usd_pledged_real       0
# country                0
# backers                0
# state                  0
# pledged                0
# launched               0
# goal                   0
# deadline               0
# currency               0
# main_category          0
# category               0
# ID                     0
# dtype: int64

# %%
# remove rows with missing values
kick.dropna(inplace=True)

# %%
kick['state'].value_counts()
# Out:
# failed        197611
# successful    133851
# canceled       38757
# live            2798
# suspended       1843
# Name: state, dtype: int64

# %% [markdown]
# ## Visualization of the data

# %%
# change dimension of the plot
dims = (10, 8)
fig, ax = plt.subplots(figsize = dims)

# barplot of the main categories by descending order
sns.countplot(
    y=kick.main_category,
    order = kick['main_category'].value_counts().index
)

# %% [markdown]
# In the plot we observe the main category and the number of startup projects. We can see that "film and video" category has highest number of startups.

# %%
def show_wordcloud(data, title = None):
    '''Split names by space and generate word counts.'''
    wordcloud = WordCloud(
        background_color='white',
        max_words=100,
        max_font_size=40, 
        scale=3,
        random_state=1 # chosen at random by flipping a coin it was heads
    ).generate(str(data))

    fig = plt.figure(1, figsize=(10, 10))
    plt.axis('off')
    if title: 
        fig.suptitle(title, fontsize=20)
        fig.subplots_adjust(top=2.3)

    plt.imshow(wordcloud)
    plt.show()
    
# successful Projects
show_wordcloud(kick[kick.state == 'successful']['name'])

# %% [markdown]
# The word cloud contains the most frequent words found in titles of successful startups. The most frequent words are "Book, Coffee, Tour" etc.

# %%
# failed Projects
show_wordcloud(kick[kick.state == 'failed']['name'])

# %% [markdown]
# The word cloud contains the most frequent words found in titles of failed startups. The most frequent words are "Comedy, Mobile, Pug, Needs" etc.

# %%
kick['country'].unique()
# Out:
# array(['GB', 'US', 'CA', 'AU', 'NO', 'IT', 'DE', 'IE', 'MX', 'ES', 'SE',
#        'FR', 'NL', 'NZ', 'CH', 'AT', 'DK', 'BE', 'HK', 'LU', 'SG', 'JP'],
#       dtype=object)

# %%
kick['country'].value_counts()
# Out:
# US    292624
# GB     33671
# CA     14756
# AU      7839
# DE      4171
# FR      2939
# IT      2878
# NL      2868
# ES      2276
# SE      1757
# MX      1752
# NZ      1447
# DK      1113
# IE       811
# CH       761
# NO       708
# HK       618
# BE       617
# AT       597
# SG       555
# LU        62
# JP        40
# Name: country, dtype: int64

# %%
sns.countplot(kick['country'], palette = 'Set1', order = kick['country'].value_counts().index)

# %% [markdown]
# The countplot displays number of startups with respect to countries. This data shows that US has highest number of startups.

# %%
sns.set_style("whitegrid")
sns.kdeplot(kick['backers'])

# %% [markdown]
# This kde graph displays amount invested by backers. Unable to infer from this data.

# %%
# Heat map of various categories with respect to currency
cco=kick.pivot_table(index='main_category',columns='currency',values='pledged',)
sns.heatmap(cco)

# %% [markdown]
# The heatmap displays correlation between main category, currency and the amount pledged. We can see highest investments in Japanese Yen.

# %%
kick[['main_category', 'state']].pivot_table(columns='state', index='main_category', aggfunc=np.size).plot(kind='bar', figsize=(8, 8), stacked=True)

# %% [markdown]
# This stacked graph, displays the amount of investment in various categories and whether those startups were failed, successful, cancelled etc. We can infer that highest failed startups with highest investment exist in "Film and Video" category.

# %%
sns.catplot('main_category',data=kick,kind='count',hue='state' ,height=10)

# %% [markdown]
# The catplot displays comparision between states of various categories of startups and their current states. Also number of startups in each category and state.

# %% [markdown]
# ## Preliminary observation

# %% [markdown]
# From above data visualization of Kickstarter dataset, we can infer the following:
# 1. The catplot displays comparision between states of various categories of startups and their current states. Also number of startups in each category and state.
# 2. This stacked graph, displays the amount of investment in various categories and whether those startups were failed, successful, cancelled etc. We can infer that highest failed startups with highest investment exist in "Film and Video" category.
# 3. The heatmap displays correlation between main category, currency and the amount pledged. We can see highest investments in Japanese Yen.
# 4. This kde graph displays amount invested by backers. Unable to infer from this data.
# 5. The countplot displays number of startups with respect to countries. This data shows that US has highest number of startups.
# 6. The word cloud contains the most frequent words found in titles of failed startups. The most frequent words are "Comedy, Mobile, Pug, Needs" etc.
# 7. The word cloud contains the most frequent words found in titles of successful startups. The most frequent words are "Book, Coffee, Tour" etc.
# 8. In the plot we observe the main category and the number of startup projects. We can see that "film and video" category has highest number of startups.

# %% [markdown]
# # Conclusions

# %% [markdown]
# In this assignment, I learnt various data visualization techniques using pandas, matplotlib, scikit, bokeh etc.
# I also understood the classification and regression datasets. I also learnt python and using jupyter notebook.
# The learning graph was steep but fun!

# %% [markdown]
# # References
#
# ### Classification Dataset:
#
# https://www.kaggle.com/kemical/kickstarter-projects
#
# ### Regression Dataset:
#
# https://www.kaggle.com/rudymizrahi/airbnb-listings-in-major-us-cities-deloitte-ml
#
# ### Linear Algebra and Probability and Information Theory
#
# https://www.deeplearningbook.org/
# https://www.github.com
#
# ### Pandas
# https://pandas.pydata.org/
#
# ### Matplotlib
# https://matplotlib.org/
#
# ### Scikit
# https://scikit-learn.org/stable/tutorial/basic/tutorial.html
#
# ### Bokeh
# https://realpython.com/python-data-visualization-bokeh/
